# %%
import sys
from pathlib import Path
sys.path.append("../..")

from src.data.structures.spectrogram import Spectrogram

# %%
sample_path = Path("..\\..\\datasets\\MelodyNet\\raw\\train\\Nintendo - The Legend of Zelda\\")
sample_name = Path("Verse")

wav_path = sample_path / "audio" / sample_name.with_suffix(".wav")
midi_path = sample_path / "labels" / sample_name.with_suffix(".mid")

# %%
spec = Spectrogram.from_audio(wav_path, f_max=8000)
spec.visualize()
# Out:
# <Axes: xlabel='Время, с', ylabel='Частота, Гц'>

# %%
spec.spectrogram.shape
# Out:
# torch.Size([1, 128, 2302])
