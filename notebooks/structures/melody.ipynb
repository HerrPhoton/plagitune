# %%
import sys
import random
from pathlib import Path
sys.path.append("../..")

from src.data.structures.melody import Melody

# %%
midi_file = Path("..\\..\\datasets\\MelodyNet\\raw\\train\\Aerosmith - Cryin\\labels\\Verse.mid")

# %%
# midis = list(Path("..\\..\\datasets\\MelodyNet\\raw\\train").rglob("*.mid"))
# midis = [str(mid) for mid in midis]

# %%
#melody = Melody.from_midi(random.choice(midis))
melody = Melody.from_midi(midi_file)
melody.visualize()
# Out:
# <Axes: xlabel='Время, с'>

# %%
#melody.to_wav("../datasets/MelodyNet/test/audio/test2.wav", sample_rate=44100)
