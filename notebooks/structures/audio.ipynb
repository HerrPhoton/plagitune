# %%
import sys
sys.path.append("../..")
from pathlib import Path

from src.data.structures.audio import Audio

# %%
file_path = Path("..\\..\\datasets\\MelodyNet\\raw\\val\\A-ha - Take on Me\\audio\\Verse.wav")

# %%
audio = Audio(file_path)
audio.visualize()
# Out:
# <Axes: xlabel='Время, с', ylabel='Амплитуда'>
