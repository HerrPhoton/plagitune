# %%
import sys
import random
from pathlib import Path
sys.path.append("..")

from src.data.structures.melody import Melody

# %%
midi_file = Path("..\\datasets\\melody_extraction\\processed\\train\\labels\\bridge_1.mid")

# %%
midis = list(Path("..\\datasets\\melody_extraction\\raw\\train").rglob("*.mid"))
midis = [str(mid) for mid in midis]

# %%
#melody = Melody.from_midi(random.choice(midis))
melody = Melody.from_midi(midi_file)
melody.visualize()
# Out:
# <Axes: xlabel='Время, с'>

# %%
melody.to_wav("../datasets/melody_extraction/test/audio/test1.wav", sample_rate=44100)
