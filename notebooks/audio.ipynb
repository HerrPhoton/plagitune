# %%
import sys
sys.path.append("..")
from pathlib import Path

from src.data.structures.audio import Audio

# %%
file_path = Path("..\\datasets\\melody_extraction\\raw\\train\\Wolfgang Amadeus Mozart - Symphony no 40\\audio\\Verse.wav")

# %%
audio = Audio(file_path)
audio.visualize()
# Out:
# <Axes: xlabel='Время, с', ylabel='Амплитуда'>
