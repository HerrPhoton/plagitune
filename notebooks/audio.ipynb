# %%
import sys
sys.path.append("..")
from pathlib import Path

from src.data.structures.audio import Audio

# %%
file_path = Path("..\\datasets\\melody_extraction\\raw\\train\\Nintendo - The Legend of Zelda\\audio\\Verse.wav")

# %%
audio = Audio(file_path)
audio.visualize()
